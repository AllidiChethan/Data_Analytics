# %% [markdown]
# # Installing all the required packages

# %%
# !pip install pandas numpy matplotlib seaborn scipy scikit-learn statsmodels
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    -- ------------------------------------- 2.1/38.5 MB 13.2 MB/s eta 0:00:03
#    --- ------------------------------------ 3.7/38.5 MB 13.1 MB/s eta 0:00:03
#    ------- -------------------------------- 6.8/38.5 MB 12.4 MB/s eta 0:00:03
#    --------- ------------------------------ 9.4/38.5 MB 12.6 MB/s eta 0:00:03
#    ------------ --------------------------- 12.3/38.5 MB 12.7 MB/s eta 0:00:03
#    --------------- ------------------------ 14.9/38.5 MB 12.8 MB/s eta 0:00:02
#    ------------------ --------------------- 17.6/38.5 MB 12.9 MB/s eta 0:00:02
#    -------------------- ------------------- 20.2/38.5 MB 12.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.1/38.5 MB 12.9 MB/s eta 0:00:02
# ...

# %% [markdown]
# ### Pandas = used for working with data( tables, excel or CSV).
# ### numpy = used to perform mathematical operation in a faster way.
# ### matplotlib = used to create visualizations.
# ### seaborn = makes statistical plots.
# ### scipy = Advanced math,stats and optimization functions.
# ### scikit-learn = machine learning library.
# ### statsmodels = Specialized in statistical tests, regression models, and hypothesis testing.

# %%
# !pip3 install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------------ --------------------- 1.8/4.0 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 11.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
